# %% [markdown]
# # Первичный анализ отзывов
# Используется обработанный набор, созданный командой `python run_all.py`.

# %%
import pandas as pd
df = pd.read_csv('data/processed/reviews_enriched.csv')
df[['rating','word_count','emotion_intensity']].describe()
