# %% [markdown]
# # Проверка гипотез H1–H5
# Расчеты выполняются теми же функциями, что и полный pipeline.

# %%
import pandas as pd
from src.hypotheses import evaluate_all
df = pd.read_csv('data/processed/reviews_enriched.csv')
results, _ = evaluate_all(df)
[(r['hypothesis'], r['verdict']) for r in results]
