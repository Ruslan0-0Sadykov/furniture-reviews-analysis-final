# %% [markdown]
# # Аудит исходных данных
# Ноутбук воспроизводит загрузку и базовый аудит трех XLSX-файлов.

# %%
from src.config import DATA_RAW
from src.data_loading import build_audit
build_audit(DATA_RAW)
